# %%
import cv2
import os
from glob import glob

# Define paths
input_folder = r'C:\Users\Samiksha Bhatia\Acne_gpu\myvenv\Data\test\images'  # Change to your dataset folder
output_folder = r'C:\Users\Samiksha Bhatia\Acne_gpu\myvenv\Data2\test\images'

# Create output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# CLAHE parameters
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))

# Process all images
image_paths = glob(os.path.join(input_folder, '*.jpg'))  # Change extension if needed
for img_path in image_paths:
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  # Read in grayscale
    if img is not None:
        enhanced_img = clahe.apply(img)  # Apply CLAHE
        
        # Save the enhanced image
        output_path = os.path.join(output_folder, os.path.basename(img_path))
        cv2.imwrite(output_path, enhanced_img)

print(f"CLAHE preprocessing completed. Processed images saved in {output_folder}.")
# Out:
# CLAHE preprocessing completed. Processed images saved in C:\Users\Samiksha Bhatia\Acne_gpu\myvenv\Data2\test\images.

# %%
import torch
from ultralytics import YOLO
import matplotlib.pyplot as plt

# %%
model = YOLO('./path/to/yolov8n.pt')

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
torch.cuda.empty_cache()

# %%
model.train(
    data='C:/Users/Samiksha Bhatia/Acne_gpu/myvenv/Data/data.yaml',  # Path to the dataset configuration file
    epochs=50,                  # Number of training epochs
    imgsz=640,                  # Image size
    batch=8,                   # Batch size
    workers=4,                  # Number of data loader workers
    save=True,              # Save training results
    device = device


)
# Out:
# New https://pypi.org/project/ultralytics/8.3.71 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.69  Python-3.11.9 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# ...

# %%
model = YOLO(r"C:\Users\Samiksha Bhatia\Acne_gpu\runs\detect\train10\weights\best.pt")

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

def draw_predictions(model, image_path):
    """
    Runs object detection on an image and draws bounding boxes with class labels and confidence scores.

    Args:
        model: Trained object detection model (e.g., YOLO).
        image_path (str): Path to the input image.

    Returns:
        Displays the image with bounding boxes and labels.
    """
    # Run model prediction
    results = model.predict(image_path)

    # Load the original image
    image = cv2.imread(image_path)
    if image is None:
        print("Error: Unable to load image. Check the file path.")
        return

    # Convert BGR to RGB (for Matplotlib)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    for result in results:
        # Get the original shape used by the model
        orig_h, orig_w = result.orig_shape  # Model input shape (e.g., 512x640)
        img_h, img_w, _ = image.shape       # Actual loaded image shape

        print(f"Model Input Shape: {orig_w}x{orig_h}")
        print(f"Displayed Image Shape: {img_w}x{img_h}")

        if len(result.boxes) > 0:
            for box in result.boxes:
                x1, y1, x2, y2 = box.xyxy[0].tolist()  # Get bounding box coordinates
                confidence = box.conf.item()  # Confidence score
                class_id = int(box.cls.item())  # Class ID
                class_name = result.names[class_id]  # Get class name

                print(f"Original Box: {x1}, {y1}, {x2}, {y2}")

                # Ensure scaling is based on correct image size
                scale_x = img_w / orig_w
                scale_y = img_h / orig_h

                x1 = int(x1 * scale_x)
                y1 = int(y1 * scale_y)
                x2 = int(x2 * scale_x)
                y2 = int(y2 * scale_y)

                print(f"Scaled Box: {x1}, {y1}, {x2}, {y2}")

                # Draw bounding box
                cv2.rectangle(image_rgb, (x1, y1), (x2, y2), (255, 0, 0), 2)

                # Add confidence score and class label
                label = f"{class_name} ({confidence:.2f})"
                cv2.putText(image_rgb, label, (x1, max(y1 - 10, 10)), 
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 1)
        else:
            print("No Detections Found.")

    # Display the image with bounding boxes
 


    plt.imshow(image_rgb)
    plt.axis("off")
    plt.show()

# %%
img = r"C:\Users\Samiksha Bhatia\Acne_gpu\myvenv\Data2\test\images\levle3_20_jpg.rf.e034d581f236adc5fa89ce0fbe2fc2f7.jpg"
draw_predictions(model, img)
# Out:
# image 1/1 C:\Users\Samiksha Bhatia\Acne_gpu\myvenv\Data2\test\images\levle3_20_jpg.rf.e034d581f236adc5fa89ce0fbe2fc2f7.jpg: 480x640 1 papules, 9 pustuless, 29.8ms
# Speed: 2.0ms preprocess, 29.8ms inference, 130.1ms postprocess per image at shape (1, 3, 480, 640)
# Model Input Shape: 600x450
# Displayed Image Shape: 600x450
# Original Box: 364.43463134765625, 408.5491027832031, 401.6308898925781, 447.5787048339844
# Scaled Box: 364, 408, 401, 447
# Original Box: 553.4590454101562, 67.26553344726562, 591.8956298828125, 103.58365631103516
# Scaled Box: 553, 67, 591, 103
# Original Box: 381.0014953613281, 161.66139221191406, 419.867919921875, 201.00546264648438
# Scaled Box: 381, 161, 419, 201
# Original Box: 324.8984375, 402.88861083984375, 370.25341796875, 441.15924072265625
# Scaled Box: 324, 402, 370, 441
# Original Box: 270.40447998046875, 311.4666748046875, 309.3230895996094, 343.42291259765625
# Scaled Box: 270, 311, 309, 343
# ...

# %%
img = r"C:\Users\Samiksha Bhatia\Acne_gpu\myvenv\Data2\test\images\01F3MMY3WTPR3X8P7DH0N0VF44_jpeg.rf.6118ad3e5e6c0932b16648e47774685b.jpg"
draw_predictions(model, img)
# Out:
# image 1/1 C:\Users\Samiksha Bhatia\Acne_gpu\myvenv\Data2\test\images\01F3MMY3WTPR3X8P7DH0N0VF44_jpeg.rf.6118ad3e5e6c0932b16648e47774685b.jpg: 512x640 1 nodules, 95.6ms
# Speed: 6.6ms preprocess, 95.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Model Input Shape: 294x222
# Displayed Image Shape: 294x222
# Original Box: 163.2278594970703, 31.129804611206055, 212.25613403320312, 75.26862335205078
# Scaled Box: 163, 31, 212, 75

# %%
img = r"myvenv\Data2\test\images\01F3MMY5FZF8N8BX849Y22JCQW_jpeg.rf.87fee93e4f2586d9f3d5bce41886304a.jpg"
draw_predictions(model,img)
# Out:
# image 1/1 c:\Users\Samiksha Bhatia\Acne_gpu\myvenv\Data2\test\images\01F3MMY5FZF8N8BX849Y22JCQW_jpeg.rf.87fee93e4f2586d9f3d5bce41886304a.jpg: 512x640 1 pustules, 90.1ms
# Speed: 4.6ms preprocess, 90.1ms inference, 6.6ms postprocess per image at shape (1, 3, 512, 640)
# Model Input Shape: 294x222
# Displayed Image Shape: 294x222
# Original Box: 158.24551391601562, 192.78359985351562, 175.6597137451172, 208.69711303710938
# Scaled Box: 158, 192, 175, 208

# %%
img = r"C:\Users\Samiksha Bhatia\Acne_gpu\myvenv\Data2\test\images\01F3MMY86R7W5CGSXKR551GQVK_jpeg.rf.bcdb4b3ce4fad87e5649cc0bdb9290ed.jpg"
draw_predictions(model, img)
# Out:
# image 1/1 C:\Users\Samiksha Bhatia\Acne_gpu\myvenv\Data2\test\images\01F3MMY86R7W5CGSXKR551GQVK_jpeg.rf.bcdb4b3ce4fad87e5649cc0bdb9290ed.jpg: 512x640 1 pustules, 93.3ms
# Speed: 7.0ms preprocess, 93.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Model Input Shape: 294x222
# Displayed Image Shape: 294x222
# Original Box: 73.88475036621094, 60.83236312866211, 136.1524200439453, 106.99491119384766
# Scaled Box: 73, 60, 136, 106

# %%
label_path = r"C:\Users\Samiksha Bhatia\Acne_gpu\myvenv\Data2\test\labels\01F3MMY86R7W5CGSXKR551GQVK_jpeg.rf.bcdb4b3ce4fad87e5649cc0bdb9290ed.txt"

# Read and print the contents
with open(label_path, "r") as file:
    content = file.read()

print(content)
# Out:
# 2 0.3673469387755102 0.38288288288288286 0.1836734693877551 0.23423423423423423

# %%
img = r"C:\Users\Samiksha Bhatia\Acne_gpu\myvenv\Data2\valid\images\levle0_454_jpg.rf.7e57f81ccccf02d0ae781fc8452bd996.jpg"
draw_predictions(model,img)
# Out:
# image 1/1 C:\Users\Samiksha Bhatia\Acne_gpu\myvenv\Data2\valid\images\levle0_454_jpg.rf.7e57f81ccccf02d0ae781fc8452bd996.jpg: 640x576 1 dark spot, 101.9ms
# Speed: 8.8ms preprocess, 101.9ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 576)
# Model Input Shape: 3112x3456
# Displayed Image Shape: 3112x3456
# Original Box: 2471.364501953125, 2008.3375244140625, 2586.520751953125, 2121.484619140625
# Scaled Box: 2471, 2008, 2586, 2121

# %%
img = r"C:\Users\Samiksha Bhatia\Acne_gpu\myvenv\Data2\test\images\levle0_63_jpg.rf.43c956938fc5804eed5d786f27c09773.jpg"
draw_predictions(model , img)
# Out:
# image 1/1 C:\Users\Samiksha Bhatia\Acne_gpu\myvenv\Data2\test\images\levle0_63_jpg.rf.43c956938fc5804eed5d786f27c09773.jpg: 448x640 6 dark spots, 80.3ms
# Speed: 7.4ms preprocess, 80.3ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# Model Input Shape: 4912x3264
# Displayed Image Shape: 4912x3264
# Original Box: 2998.98193359375, 1686.37451171875, 3160.142578125, 1873.1505126953125
# Scaled Box: 2998, 1686, 3160, 1873
# Original Box: 3163.88232421875, 1312.4317626953125, 3321.861572265625, 1456.669677734375
# Scaled Box: 3163, 1312, 3321, 1456
# Original Box: 3265.4541015625, 1485.685302734375, 3404.53662109375, 1622.0477294921875
# Scaled Box: 3265, 1485, 3404, 1622
# Original Box: 3408.363525390625, 2275.068603515625, 3621.163818359375, 2471.04052734375
# Scaled Box: 3408, 2275, 3621, 2471
# Original Box: 2976.98876953125, 1668.5596923828125, 3198.060546875, 1903.1505126953125
# Scaled Box: 2976, 1668, 3198, 1903
# ...

# %%
label_path = r"C:\Users\Samiksha Bhatia\Acne_gpu\myvenv\Data2\test\labels\levle0_63_jpg.rf.43c956938fc5804eed5d786f27c09773.txt"

# Read and print the contents
with open(label_path, "r") as file:
    content = file.read()

print(content)
# Out:
# 1 0.7193627850162867 0.3648897058823529 0.0372557003257329 0.05024509803921569
# 1 0.6613395765472313 0.42769607843137253 0.033184039087947884 0.04718137254901961
# 1 0.5951750814332247 0.45067401960784315 0.04132736156351791 0.04411764705882353
# 1 0.6816978827361564 0.48284313725490197 0.03399837133550489 0.0508578431372549
# 1 0.6328379478827362 0.5456495098039216 0.05150651465798046 0.056372549019607844
# 1 0.7168159609120521 0.7264093137254902 0.03623778501628665 0.05024509803921569
# 1 0.560057003257329 0.8596813725490197 0.03013029315960912 0.05330882352941176

# %%
img = r"C:\Users\Samiksha Bhatia\Acne_gpu\myvenv\Data2\test\images\01F3MMY37WC5S8V9A3VD4X56PT_jpeg.rf.4111bfb93591b430b4acabee3e6c0519.jpg"
draw_predictions(model, img)
# Out:
# image 1/1 C:\Users\Samiksha Bhatia\Acne_gpu\myvenv\Data2\test\images\01F3MMY37WC5S8V9A3VD4X56PT_jpeg.rf.4111bfb93591b430b4acabee3e6c0519.jpg: 512x640 1 papules, 93.4ms
# Speed: 5.5ms preprocess, 93.4ms inference, 5.3ms postprocess per image at shape (1, 3, 512, 640)
# Model Input Shape: 294x222
# Displayed Image Shape: 294x222
# Original Box: 90.77300262451172, 126.56134033203125, 110.44715118408203, 142.53036499023438
# Scaled Box: 90, 126, 110, 142

# %%
img = r"C:\Users\Samiksha Bhatia\Acne_gpu\myvenv\Data2\test\images\levle0_271_jpg.rf.ff3bef30d09f446c3a43e66314b434fb.jpg"
draw_predictions(model, img)
# Out:
# image 1/1 C:\Users\Samiksha Bhatia\Acne_gpu\myvenv\Data2\test\images\levle0_271_jpg.rf.ff3bef30d09f446c3a43e66314b434fb.jpg: 640x576 (no detections), 103.5ms
# Speed: 14.1ms preprocess, 103.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
# Model Input Shape: 3112x3456
# Displayed Image Shape: 3112x3456
# No Detections Found.

# %%
img = r"C:\Users\Samiksha Bhatia\Acne_gpu\myvenv\Data2\test\images\levle3_76_jpg.rf.f513e4d10ceb736c0f460f00b8567a7f.jpg"
draw_predictions(model, img)
